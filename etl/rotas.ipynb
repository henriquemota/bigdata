# %%
import pandas as pd

# %%
df = pd.read_excel("rotas.xls", skiprows=12)
df.head()
# Out:
#   Ord Unnamed: 1                   Route Name Class.           Created in  \
# 0   1   Route ID  Messejana/Papicu/Cambeba/TJ   CMPr  1999-06-07 00:00:00
# 1   2         11                   Circular I   CNVr  1968-11-28 00:00:00
# 2   3         12                  Circular II   CNVr  1968-11-28 00:00:00
# 3   4         13                  Aguanambi I   CNVr  1977-01-01 00:00:00
# 4   5         14                 Aguanambi II   CNVr  1977-01-01 00:00:00
#
#   Type            Last Trip    Company ID Going C. Back  ... Created  \
# 0    1  2014-11-28 00:00:00  02 Fortaleza  18.1    16.6  ...    31.2
# 1    1  2013-11-09 00:00:00   35 Vega S/A  11.8     5.7  ...      17
# 2    1  2015-04-18 00:00:00  41 Terra Luz   6.2    10.6  ...    16.7
# 3    1  2013-11-09 00:00:00   12 São José   8.3     6.1  ...    13.1
# 4    1  2014-10-30 00:00:00  26 Maraponga   4.6     7.1  ...      12
#
#   Difference Bus Termials Unnamed: 14 Unnamed: 15 Unnamed: 16 Vichicle Type  \
# ...

# %%
df.tail()
# Out:
#     Bus routes in Fortaleza. Technician: João BELO dos Santos  \
# 452                                               ESP-
# 453                                                NaN
# 454  Convencional: Não incluída a terminal de ônibu...
# 455  Convencional: Não incluída a terminal de ônibu...
# 456  Convencional: Não incluída a terminal de ônibu...
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 452  Especial (Special): Special operations for eve...        NaN        NaN
# 453                                                NaN        NaN        NaN
# 454                                                NaN        NaN        NaN
# 455                                                NaN        NaN        NaN
# 456                                                NaN        NaN        NaN
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 452        NaN        NaN        NaN        NaN        NaN        NaN  ...
# ...
